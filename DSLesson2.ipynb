# %%
import pandas
data_df=pandas.read_csv("data.csv")
data_df
# Out:
#     Flour  Milk  Sugar  Butter  Egg  Baking Powder  Vanilla  Salt     Type
# 0      55    28      3       7    5              2        0     0   Muffin
# 1      47    24     12       6    9              1        0     0   Muffin
# 2      47    23     18       6    4              1        0     0   Muffin
# 3      45    11     17      17    8              1        0     0   Muffin
# 4      50    25     12       6    5              2        1     0   Muffin
# 5      55    27      3       7    5              2        1     0   Muffin
# 6      54    27      7       5    5              2        0     0   Muffin
# 7      47    26     10      10    4              1        0     0   Muffin
# 8      50    17     17       8    6              1        0     0   Muffin
# 9      50    17     17      11    4              1        0     0   Muffin
# 10     39     0     26      19   14              1        1     0  Cupcake
# ...

# %%
data_df.describe()
# Out:
#            Flour       Milk      Sugar     Butter        Egg  Baking Powder  \
# count  50.000000  50.000000  50.000000  50.000000  50.000000      50.000000
# mean   39.340000  15.920000  23.080000   9.740000   6.940000       2.680000
# std    11.213348   8.090912  14.037617   4.898188   3.644453       3.152194
# min    19.000000   0.000000   3.000000   3.000000   0.000000       0.000000
# 25%    34.000000  11.000000  16.000000   6.000000   5.000000       1.000000
# 50%    39.000000  17.000000  20.000000   8.000000   6.000000       1.000000
# 75%    47.750000  23.000000  26.000000  12.000000   9.000000       2.000000
# max    55.000000  28.000000  52.000000  20.000000  14.000000      11.000000
#
#          Vanilla       Salt
# count  50.000000  50.000000
# mean    0.960000   0.960000
# std     2.732719   1.989359
# min     0.000000   0.000000
# 25%     0.000000   0.000000
# 50%     0.000000   0.000000
# 75%     1.000000   0.000000
# max    14.000000   6.000000

# %%
data_df.corr()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9492\3493117147.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_df.corr()
#                   Flour      Milk     Sugar    Butter       Egg  \
# Flour          1.000000  0.798401 -0.922253  0.108653 -0.194750
# Milk           0.798401  1.000000 -0.813199 -0.154508 -0.326149
# Sugar         -0.922253 -0.813199  1.000000 -0.242480 -0.030222
# Butter         0.108653 -0.154508 -0.242480  1.000000  0.335220
# Egg           -0.194750 -0.326149 -0.030222  0.335220  1.000000
# Baking Powder -0.658527 -0.509946  0.711774 -0.470761 -0.362329
# Vanilla       -0.372507 -0.334281  0.159687 -0.186802  0.471062
# Salt          -0.774266 -0.649380  0.828842 -0.493268 -0.160785
#
#                Baking Powder   Vanilla      Salt
# ...

# %%
# split into train and test data
array=data_df.values
# x-train data
X=array[:, 0:8]  #the features predict the outcome (from flour to salt )
Y=array[:, 8] # the outcome (type)
